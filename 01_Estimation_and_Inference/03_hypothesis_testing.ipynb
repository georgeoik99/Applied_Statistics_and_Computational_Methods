# %% [markdown]
# # Hypothesis Testing
#
# A structured roadmap from statistical hypotheses to hand calculations and Python verification.

# %% [markdown]
# ## 1. Learning objectives
#
# **TODO:** Define the inferential questions and expected outcomes.

# %% [markdown]
# ## 2. Null and alternative hypotheses
#
# **TODO:** Cover simple/composite and one-sided/two-sided alternatives.

# %% [markdown]
# ## 3. Significance level, test statistic, rejection region, and p-value
#
# **TODO:** Connect the four elements conceptually and graphically.

# %% [markdown]
# ## 4. Type I error, Type II error, and power
#
# **TODO:** Define $\alpha$, $\beta$, and power $1-\beta$ with a small simulation.

# %% [markdown]
# ## 5. Parametric tests
#
# **TODO:** Organize one-sample, two-sample, Welch, and paired t-tests; add variance and proportion tests where appropriate.

# %% [markdown]
# ## 6. Assumptions and non-parametric alternatives
#
# **TODO:** Include normality checks and a Wilcoxon-based comparison without treating assumption tests mechanically.

# %% [markdown]
# ## 7. From-scratch calculation and SciPy verification
#
# **TODO:** Calculate test statistics and p-values manually before checking them with SciPy.

# %% [markdown]
# ## 8. Interpretation and reporting
#
# **TODO:** Separate statistical significance, uncertainty, effect size, and practical importance.

# %% [markdown]
# ## 9. References
#
# **TODO:** Cite *Κεφάλαιο 2 hypothesis-testing* and the testing examples in *Introduction To R*.
