# %% [markdown]
# # Sampling Distributions and the Central Limit Theorem
#
# A structured roadmap linking theory, normal approximations, and Monte Carlo experiments.

# %% [markdown]
# ## 1. Learning objectives
#
# **TODO:** State the distinction between a population distribution and a sampling distribution.

# %% [markdown]
# ## 2. Sampling distributions
#
# **TODO:** Explore the sampling distributions of the sample mean and selected estimators.

# %% [markdown]
# ## 3. Central Limit Theorem
#
# **TODO:** State the CLT, standardization, assumptions, and common interpretation errors.

# %% [markdown]
# ## 4. Exercise 7: sum of Uniform(0, 1) variables
#
# For $X_1,\ldots,X_{10}\sim U(0,1)$, study $P(\sum X_i>6)$ via a normal approximation.
#
# **TODO:** Derive the mean and variance of the sum, standardize the threshold, and calculate the CLT approximation.

# %% [markdown]
# ## 5. Monte Carlo verification
#
# **TODO:** Estimate the probability from simulation and compare it with the normal approximation (and, optionally, the exact Irwin-Hall result).

# %% [markdown]
# ## 6. Exponential cross-link
#
# **TODO:** Revisit the exponential example from `01_parameter_estimation.ipynb`, focusing here on how the estimator's sampling distribution changes as $n$ grows.

# %% [markdown]
# ## 7. Accuracy and limitations
#
# **TODO:** Investigate sample size, skewness, tail probabilities, and when a normal approximation is weak.

# %% [markdown]
# ## 8. References
#
# **TODO:** Cite Exercise 7 and the distribution/random-generation material in *Introduction To R*.
